# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('california_housing.csv')
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
from sklearn.datasets import fetch_california_housing
california_housing = fetch_california_housing(as_frame=True)
df_ca = california_housing.frame
df_ca
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
df_ca.to_csv("california_housing.csv", index=False)
import pandas as pd
df_ca2 = pd.read_csv("california_housing.csv")
df_ca2.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
#creating X as features/independent variables and y as target/dependent variable
X = df_ca[['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup']]
y = df_ca['MedHouseVal']

# %%
#Create train and test data
#Split the data into 80% training dataset and 20% test dataset.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=123)

# %%
#Perform Linear Regression
from sklearn.linear_model import LinearRegression 
from sklearn import metrics
from sklearn.metrics import mean_squared_error

reg = LinearRegression() 
  
reg.fit(X_train, y_train) 

print(reg.coef_)
print(reg.intercept_)
# Out:
# [ 0.54149966  0.01565006 -0.21978449  1.01319096 -0.00446647]
# -0.378947627131232

# %%
#root mean squared error (RMSE) from Linear Regression
y_pred = reg.predict(X_test)
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 0.7856766789029451

# %%
x = np.arange(50)

plt.rcParams["figure.figsize"] = (12,4)
plt.plot(x, y_pred[:50], c = "red")
plt.plot(x, y_test[:50], c = "blue")
plt.show()

# %%
X1_train = X_train[['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms']]
X1_test = X_test[['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms']]

# %%
reg2 = LinearRegression() 
  
reg2.fit(X1_train, y_train) 

print(reg2.coef_)
print(reg2.intercept_)

y_pred = reg2.predict(X1_test)
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# [ 0.54043044  0.01559194 -0.21880795  1.0091316 ]
# -0.38768096647176487
# 0.787504011331308
